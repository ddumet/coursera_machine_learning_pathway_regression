# %% [markdown]
# # Regression Week 2: Multiple Regression (Interpretation)

# %% [markdown]
# The goal of this first notebook is to explore multiple regression and feature engineering.
#
# In this notebook you will use data on house sales in King County to predict prices using multiple regression. You will:
# * Use **Pandas/Numpy** to do some feature engineering
# * Use **Scikit-learn** to compute the regression weights (coefficients/parameters)
# * Given the regression weights, predictors and outcome write a function to compute the Residual Sum of Squares
# * Look at coefficients and interpret their meanings
# * Evaluate multiple models via RSS

# %% [markdown]
# # Imports

# %%
# Standard libs
import pandas as pd
import numpy as np

# %%
# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
from math import log

# %% [markdown]
# # Load in house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
house_sales_datatype={'bathrooms':float, 'waterfront':int, 'sqft_above':int,
                      'sqft_living15':float, 'grade':int, 'yr_renovated':int,
                      'price':float, 'bedrooms':float, 'zipcode':str, 'long':float,
                      'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int,
                      'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str,
                      'sqft_lot':int, 'view':int}

# %%
sales = pd.read_csv("./data/kc_house_data.csv", dtype=house_sales_datatype)

# %%
sales.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0       3.0       1.00       1180.0
# 1  6414100192  20141209T000000   538000.0       3.0       2.25       2570.0
# 2  5631500400  20150225T000000   180000.0       2.0       1.00        770.0
# 3  2487200875  20141209T000000   604000.0       4.0       3.00       1960.0
# 4  1954400510  20150218T000000   510000.0       3.0       2.00       1680.0
# 5  7237550310  20140512T000000  1225000.0       4.0       4.50       5420.0
# 6  1321400060  20140627T000000   257500.0       3.0       2.25       1715.0
# 7  2008000270  20150115T000000   291850.0       3.0       1.50       1060.0
# 8  2414600126  20150415T000000   229500.0       3.0       1.00       1780.0
# 9  3793500160  20150312T000000   323000.0       3.0       2.50       1890.0
#
#    sqft_lot floors  waterfront  view     ...      grade  sqft_above  \
# ...

# %% [markdown]
# # Load training and test data
# Load training and test data from the files provided with the course assignment.

# %%
train_data = pd.read_csv("./data/kc_house_train_data.csv", dtype=house_sales_datatype)
test_data = pd.read_csv("./data/kc_house_test_data.csv", dtype=house_sales_datatype)

# %% [markdown]
# # Learning a multiple regression model

# %% [markdown]
# Using Sciki-learn, fit a multiple regression model on training data predicting 'price' based on the following features:
#
# example_features = **['sqft_living', 'bedrooms', 'bathrooms']**

# %%
example_features = ["sqft_living", "bedrooms", "bathrooms"]
X_train = train_data[example_features]
y_train = train_data["price"]

# %%
example_model = LinearRegression()
example_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Now that we have fitted the model we can extract the regression weights (coefficients)

# %%
example_weight_summary = np.append(example_model.intercept_,example_model.coef_)
print("example_weight_summary:",example_weight_summary)
# Out:
# example_weight_summary: [ 87912.86581496    315.40669062 -65081.88711588   6942.16598637]

# %% [markdown]
# # Making Predictions
#
# Once a model is built we can use the .predict() function to find the predicted values for data we pass. For example using the example model above:

# %%
example_predictions = example_model.predict(X_train)
print("example_predictions[0]", example_predictions[0]) # should be 271789.505878
# Out:
# example_predictions[0] 271789.26538

# %% [markdown]
# # Compute RSS

# %% [markdown]
# Now that we can make predictions given the model, let's write a function to compute the RSS of the model. Complete the function below to calculate RSS given the model, data, and the outcome.

# %%
def get_residual_sum_of_squares(model, data, outcome):
    # First get the predictions
    y_predict = model.predict(data) 

    # Compute RSS
    RSS = (np.square(outcome - y_predict).sum())

    return(RSS)

# %% [markdown]
# Test your function by computing the RSS on **TEST** data for the example model:

# %%
X_test = test_data[example_features]
y_test = test_data["price"]

# %%
rss_example_train = get_residual_sum_of_squares(example_model, X_test, y_test)
print("rss_example_train:", rss_example_train) # should be 2.7376153833e+14
# Out:
# rss_example_train: 273761940583133.97

# %% [markdown]
# **Comparing our function with scikit-learn mean_squared_error**
# scikit-learn mean_square_error = RSS/N
#
# with N=number of observations

# %%
mse = mean_squared_error(y_test,example_model.predict(X_test),multioutput="uniform_average")
msebyN = mse*y_test.shape[0]
print("mean_squared_error (scikit-learn):",round(mse,2))
print("mean_squared_error * N number of observations:",round(msebyN,2))
# Out:
# mean_squared_error (scikit-learn): 64734438539.4
# mean_squared_error * N number of observations: 2.73761940583e+14

# %% [markdown]
# # Create some new features

# %% [markdown]
# Although we often think of multiple regression as including multiple different features (e.g. **# of bedrooms, squarefeet, and # of bathrooms**), we can also consider transformations of existing features e.g. the log of the squarefeet or even "interaction" features such as the product of bedrooms and bathrooms.

# %% [markdown]
# Next create the following 4 new features as column in both TEST and TRAIN data:
# * bedrooms_squared = bedrooms\*bedrooms
# * bed_bath_rooms = bedrooms\*bathrooms
# * log_sqft_living = log(sqft_living)
# * lat_plus_long = lat + long
# As an example here's the first one:

# %%
# bedrooms_squared
train_data["bedrooms_squared"] = train_data["bedrooms"].apply(lambda x: x**2)
test_data["bedrooms_squared"] = test_data["bedrooms"].apply(lambda x: x**2)

# bed_bath_rooms
train_data["bed_bath_rooms"] = train_data["bedrooms"] * train_data["bathrooms"]
test_data["bed_bath_rooms"] = test_data["bedrooms"] * test_data["bathrooms"]

# log_sqft_living
train_data["log_sqft_living"] = train_data["sqft_living"].apply(lambda x: log(x))
test_data["log_sqft_living"] = test_data["sqft_living"].apply(lambda x: log(x))

#lat_plus_long
train_data["lat_plus_long"] = train_data["lat"] + train_data["long"]
test_data["lat_plus_long"] = test_data["lat"] + test_data["long"]

# %%
train_data.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0       3.0       1.00       1180.0
# 1  6414100192  20141209T000000   538000.0       3.0       2.25       2570.0
# 2  5631500400  20150225T000000   180000.0       2.0       1.00        770.0
# 3  2487200875  20141209T000000   604000.0       4.0       3.00       1960.0
# 4  1954400510  20150218T000000   510000.0       3.0       2.00       1680.0
# 5  7237550310  20140512T000000  1225000.0       4.0       4.50       5420.0
# 6  1321400060  20140627T000000   257500.0       3.0       2.25       1715.0
# 7  2008000270  20150115T000000   291850.0       3.0       1.50       1060.0
# 8  2414600126  20150415T000000   229500.0       3.0       1.00       1780.0
# 9  3793500160  20150312T000000   323000.0       3.0       2.50       1890.0
#
#    sqft_lot floors  waterfront  view      ...        yr_renovated  zipcode  \
# ...

# %% [markdown]
# * Squaring bedrooms will increase the separation between not many bedrooms (e.g. 1) and lots of bedrooms (e.g. 4) since 1^2 = 1 but 4^2 = 16. Consequently this feature will mostly affect houses with many bedrooms.
# * bedrooms times bathrooms gives what's called an "interaction" feature. It is large when *both* of them are large.
# * Taking the log of squarefeet has the effect of bringing large values closer together and spreading out small values.
# * Adding latitude to longitude is totally non-sensical but we will do it anyway (you'll see why)

# %% [markdown]
# **Quiz Question: What is the mean (arithmetic average) value of your 4 new features on TEST data? (round to 2 digits)**

# %%
print("Mean bedrooms_squared on TEST data:",round(test_data["bedrooms_squared"].mean(),2))
print("Mean bed_bath_rooms on TEST data:",round(test_data["bed_bath_rooms"].mean(),2))
print("Mean log_sqft_living on TEST data:",round(test_data["log_sqft_living"].mean(),2))
print("Mean lat_plus_long on TEST data:",round(test_data["lat_plus_long"].mean(),2))
# Out:
# Mean bedrooms_squared on TEST data: 12.45
# Mean bed_bath_rooms on TEST data: 7.5
# Mean log_sqft_living on TEST data: 7.55
# Mean lat_plus_long on TEST data: -74.65

# %% [markdown]
# # Learning Multiple Models

# %% [markdown]
# Now we will learn the weights for three (nested) models for predicting house prices. The first model will have the fewest features the second model will add one more feature and the third will add a few more:
# * Model 1: squarefeet, # bedrooms, # bathrooms, latitude & longitude
# * Model 2: add bedrooms\*bathrooms
# * Model 3: Add log squarefeet, bedrooms squared, and the (nonsensical) latitude + longitude

# %%
model_1_features = ["sqft_living", "bedrooms", "bathrooms", "lat", "long"]
model_2_features = model_1_features + ["bed_bath_rooms"]
model_3_features = model_2_features + ["bedrooms_squared", "log_sqft_living", "lat_plus_long"]

# %% [markdown]
# Now that you have the features, learn the weights for the three different models and look at the value of the weights/coefficients.

# %% [markdown]
# ### Model 1

# %%
X_train_model_1 = train_data[model_1_features]
y_train = train_data["price"]

model_1 = LinearRegression()
model_1.fit(X_train_model_1, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Model 2

# %%
X_train_model_2 = train_data[model_2_features]

model_2 = LinearRegression()
model_2.fit(X_train_model_2, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Model 3

# %%
X_train_model_3 = train_data[model_3_features]

model_3 = LinearRegression()
model_3.fit(X_train_model_3, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Get coefficients for all models

# %%
print("coefficients for model_1:",np.append(model_1.intercept_,model_1.coef_))
print("coefficients for model_2:",np.append(model_2.intercept_,model_2.coef_))
print("coefficients for model_3:",np.append(model_3.intercept_,model_3.coef_))
# Out:
# coefficients for model_1: [ -6.90757268e+07   3.12258646e+02  -5.95865332e+04   1.57067421e+04
#    6.58619264e+05  -3.09374351e+05]
# coefficients for model_2: [ -6.68679689e+07   3.06610053e+02  -1.13446368e+05  -7.14613083e+04
#    6.54844630e+05  -2.94298969e+05   2.55796520e+04]
# coefficients for model_3: [ -6.20360850e+07   5.29422820e+02   3.45142296e+04   6.70607813e+04
#    5.34085611e+05  -4.06750711e+05  -8.57050439e+03  -6.78858667e+03
#   -5.61831484e+05   1.27334900e+05]

# %% [markdown]
# **Quiz Question: What is the sign (positive or negative) for the coefficient/weight for 'bathrooms' in model 1?**
#
# bathrooms is **third** features so associated with **fourth** coefficient, here for **model_1: 1.57** so **POSITIVE**

# %% [markdown]
# **Quiz Question: What is the sign (positive or negative) for the coefficient/weight for 'bathrooms' in model 2?**
#
# bathrooms is **third** features so associated with **fourth** coefficient, here for **model_2: -7.14** so **NEGATIVE**

# %% [markdown]
# # Comparing multiple models
#
# Now that you've learned three models and extracted the model weights we want to evaluate which model is best.

# %% [markdown]
# First use your functions from earlier to compute the RSS on TRAINING Data for each of the three models.

# %%
RSS = pd.DataFrame([get_residual_sum_of_squares(model_1, X_train_model_1, y_train),
                    get_residual_sum_of_squares(model_2, X_train_model_2, y_train),
                    get_residual_sum_of_squares(model_3, X_train_model_3, y_train)],
                   index=["model_1","model_2","model_3"],
                   columns=["RSS_train"],
                   dtype=float)

# %%
RSS
# Out:
#             RSS_train
# model_1  9.678800e+14
# model_2  9.584196e+14
# model_3  9.034365e+14

# %% [markdown]
# **Quiz Question: Which model (1, 2 or 3) has lowest RSS on TRAINING Data?** Is this what you expected?

# %%
RSS["RSS_train"].idxmin()
# Out:
# 'model_3'

# %% [markdown]
# Now compute the RSS on on TEST data for each of the three models.

# %%
X_test_model_1 = test_data[model_1_features]
X_test_model_2 = test_data[model_2_features]
X_test_model_3 = test_data[model_3_features]

y_test = test_data["price"]

# %%
RSS["RSS_test"] = [get_residual_sum_of_squares(model_1, X_test_model_1, y_test),
                    get_residual_sum_of_squares(model_2, X_test_model_2, y_test),
                    get_residual_sum_of_squares(model_3, X_test_model_3, y_test)]

# %%
RSS
# Out:
#             RSS_train      RSS_test
# model_1  9.678800e+14  2.255005e+14
# model_2  9.584196e+14  2.233775e+14
# model_3  9.034365e+14  2.592363e+14

# %% [markdown]
# **Quiz Question: Which model (1, 2 or 3) has lowest RSS on TESTING Data?** Is this what you expected?Think about the features that were added to each model from the previous.

# %%
RSS["RSS_test"].idxmin()
# Out:
# 'model_2'
